# %% [markdown]
# <a href="https://colab.research.google.com/github/lainIvakuraa/machineLearning/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22%D0%97%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_2_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Задание по практике 2

# %%
# !pip install pandas
# !pip install seaborn

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ##Введение в описательную статистику

# %% [markdown]
# 1. Выберите категориальную целевую переменную (**Y**)
#
# 2. Выберите переменную для анализа относительно категории (**X**)
#
# 3. Выведитие обобщенную статистическую информацию переменной (**X**)
#
# 2. Вычислите среднее, медиану, моду, минимум, максимум, стандартное отклонение относительно целевой пременной из файла Classification datasets в соответствии с вашим вариантом
#
# 3. Сделайте вывод относительно полученных результатов
#
# p.s если у вас нет категориальных признаков - преобразуйте любой числовой в категориальный (https://pandas.pydata.org/docs/reference/api/pandas.cut.html). Важно **не** использовать преобразованный Y вместе с этим же X (то есть, если вы преобразовали возраст в категорию, то вы не моежет использовать возраст в качестве X и возраст категорию в качестве Y)

# %%
df = pd.read_csv("/content/Global YouTube Statistics.csv", encoding='windows-1252')
df
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 992   993                       Panda     12300000  2.214684e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#              category                       Title  uploads         Country  \
# 0               Music                    T-Series    20082           India
# ...

# %%
df['category']= df["category"].astype("category")
describe =  df['category'].describe(include="all")
describe
df['category'].value_counts()
# Out:
# Entertainment            241
# Music                    202
# People & Blogs           132
# Gaming                    94
# Comedy                    69
# Film & Animation          46
# Education                 45
# Howto & Style             40
# News & Politics           26
# Science & Technology      17
# Shows                     13
# Sports                    11
# Pets & Animals             4
# Trailers                   2
# Autos & Vehicles           2
# Nonprofits & Activism      2
# Movies                     2
# Travel & Events            1
# Name: category, dtype: int64

# %%
mean = df['subscribers'].mean()
mean
# Out:
# 22982412.06030151

# %%
median = df['subscribers'].median()
median
# Out:
# 17700000.0

# %%
mode = df['subscribers'].mode()
mode
# Out:
# 0    12500000
# Name: subscribers, dtype: int64

# %%
min = df['subscribers'].min()
min
# Out:
# 12300000

# %%
max = df['subscribers'].max()
max
# Out:
# 245000000

# %%
std = df['subscribers'].std()
std
# Out:
# 17526105.340935983

# %% [markdown]
# Вычислите следующие квантили: 25%, 50% (медиана), 75% для числового признака вашего датасета. Затем найдите интерквартильный размах.

# %%
q1 = df['subscribers'].quantile(0.25)
q1
# Out:
# 14500000.0

# %%
q2 = df['subscribers'].quantile(0.5)
q2
# Out:
# 17700000.0

# %%
q3 = df['subscribers'].quantile(0.75)
q3
# Out:
# 24600000.0

# %%
iqr = q3-q1
iqr
# Out:
# 10100000.0

# %% [markdown]
# Какие выводы можно сделать исходя из полученных статистических данных?

# %% [markdown]
# видно, что медиана и первый квантиль отличается на 300к, в то время как разница между медианой и 3 квантилем составляет чуть меньше миллиона, что говорит о том, что каналов в датасете с количством подписчиков 1.3-1.5млн больше, чем с 1.5+
#
# ```
# Example: видим, что среднее и отклонение различается между группами, следовательно...
# Сделать подобные выводы относительно других статистических характеристик
# ```

# %% [markdown]
# ##Основы визуализации

# %% [markdown]
#  Постройте гистограмму переменной (X) относительно категориального признака (Y) из своего датасета.

# %%
#d = {'category': df['category'], 'subscribers': df['subscribers']}

#df3 = pd.DataFrame(data=d)

#df
df2 = df.copy()
df2_grouped = df2.groupby(['category'])['subscribers'].median().reset_index()
#df2 = df2.drop(df2[df2['category'] == 'nan'].index)
plt.figure(figsize=(20,6))
plt.bar(df2_grouped['category'], df2_grouped['subscribers'])
plt.title('Гистограмма количества подписчиков от категории')
plt.xlabel('Категория')
plt.ylabel('Количество подписчиков')
# Out:
# Text(0, 0.5, 'Количество подписчиков')

# %% [markdown]
# Постройте boxplot любого признака из своего датасета.
#
# 1) boxplot числовой переменной;
#
# 2) boxplot числовой переменной относительно категориальный переменной;
#
# *p.s. Если у вас только один числовой признак, преобразуйте категориальный при помощи LabelEncoder (https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html)*

# %%
plt.figure(figsize=(4, 3))
sns.boxplot(data=df['subscribers'], color='lightgreen')
plt.title('Boxplot количества подписчиков')
plt.xlabel('Возраст')
plt.show()

# %%
sns.boxplot(y=df['category'], x=df['subscribers'])
plt.title('Гистограмма количества подписчиков от категории')
plt.xlabel('Категория')
plt.ylabel('Количество подписчиков')
plt.show()

# %% [markdown]
# Постройте диаграмму рассеивания для числовых признаков вашего датасета.
#
# *p.s. Если у вас только один числовой признак, преобразуйте категориальный при помощи LabelEncoder (https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html)*

# %%
plt.figure(figsize=(4, 3))
sns.scatterplot(x='subscribers', y='video views', data=df, color='purple')
plt.title('Диаграмма количества подписчиков и просмотров')
plt.xlabel('кол-во подписчиков')
plt.ylabel('просмотры')
plt.show()
plt.figure(figsize=(4, 3))
sns.scatterplot(x='subscribers', y='subscribers_for_last_30_days', data=df, color='purple')
plt.title('Диаграмма количества подписчиков и просмотров')
plt.xlabel('кол-во подписчиков')
plt.ylabel('просмотры')
plt.show()

# %% [markdown]
# Постройте матрицу корреляции для двух числовых признаков вашего датасета.

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-15fd0fbf6174> in <cell line: 1>()
# ----> 1 df.heads()
#
# NameError: name 'df' is not defined

# %%
# Вычисление корреляционной матрицы
d = {'subscribers': df['subscribers'],'video views':  df['video views'], 'subscribers_for_last_30_days':df['subscribers_for_last_30_days'], 'created_year':df['created_year']}
df_corr = pd.DataFrame(data = d)
corr_matrix = df_corr.corr(method='pearson', numeric_only=True)

# Визуализация корреляции
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# На основании матрицы коореляции можно сделать вывод о том, что просмотры влияют на количество подписчиков, а год создания никак не влияет на их количество, то есть старые каналы не имеют преймущества над новыми

# %% [markdown]
# **Ответ здесь**

# %% [markdown]
# ##Задание для гениев*

# %% [markdown]
# Реализовать следующие методы поиска выбросов:
# 1. На основе среднего и отклонения
# 2. Критерий Шовене
# 3. С помощью квартилей
# 4. Поиск выбросов по двум переменным
#
# [Посмотреть](http://course.omgtu.ru/wp-content/uploads/2021/04/3_%D0%92%D1%8B%D0%B1%D1%80%D0%BE%D1%81%D1%8B.pdf)
#
# P.S. в качестве возвразаемого значения методов может быть:
# 1. очищенный датафрейм
# 2. индексы выбросов ```df.series.index```

# %%
"""

Ваш код здесь

"""

# %% [markdown]
# ### Пример реализации одного метода

# %%
from statistics import median, mean

class Outline:
  def __init__(self, df):
    self.df = df

  def delete_outline_by_mean(self, column_name):
    mean_data = mean(self.df[column_name])
    maximum = mean_data * 2
    result = []

    for item in self.df[column_name]:
      if abs(item - mean_data) < maximum:
        result.append(item)

    return result

# %%
data = pd.DataFrame(
    data = {
        "col1": [1, 2, 3, 4, 5, 1000],
        "col2": [1, 2, 3, 2, 1, 4]
    }
)

so = Outline(data)
so.delete_outline_by_mean("col1")
# Out:
# [1, 2, 3, 4, 5]
